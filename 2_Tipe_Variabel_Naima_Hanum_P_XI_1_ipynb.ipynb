# %% [markdown]
# <a href="https://colab.research.google.com/github/naimahanum/KKASmt1/blob/main/2_Tipe_Variabel_Naima_Hanum_P_XI_1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Naima Hanum Pratiwi
#
# Kelas: XI.1
#
# No.absen: 27

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "naimahanum789@gmail.com"

print(email_user_1)
# Out:
# naimahanum789@gmail.com

# %%
sabun_lifebuoy = 15000

print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
# Tidak boleh menggunakan spasi
nama siswa = "Hanum"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-480097681.py", line 3
#     nama siswa = "Hanum"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "Hanum"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-715193212.py", line 3
#     1_nama_siswa = "Hanum"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Hanum"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2855529703.py in <cell line: 0>()
#       2 nama_siswa_1 = "Hanum"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci di Bahasa phyton
prin = "Hanum"

print(prin)
# Out:
# Hanum

# %%
end = "Hanum"

print(end)
# Out:
# Hanum

# %%
#Deskriptif
_ = "Hanum"

print(_)
# Out:
# Hanum

# %%
# Tidak boleh pakai kata kunci phyton
# Kalau error, harus disconnect dulu
# print = "Hanum"

# print(print)

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Hanum"
nama_siswa_3 = "Andini"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Hanum
# Andini

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Alya", "Alfa"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Alya
# Alfa

# %% [markdown]
# ##Assign ke Banyak Variabel Sekaligus

# %%
nilai_hanum = nilai_cia = 100


print(nilai_hanum)
print(nilai_cia)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok *jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima-harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama  = "Hanum"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang =-2.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-508063834.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input(" Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f" Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
#  Masukkan lebar persegi: 10
#  Luas persegi panjang adalah 40 cm^2

# %%
panjang_3 = int(input("Masukkan panjang balok: "))
lebar_3 = int(input(" Masukkan lebar balok: "))
tinggi_3 = int(input(" Masukkan tinggi balok: "))

volume_3 = panjang_3*lebar_3*tinggi_3

print(f" Volume balok adalah {volume_3} cm³")
# Out:
# Masukkan panjang balok: 10
#  Masukkan lebar balok: 5
#  Masukkan tinggi balok: 4
#  Volume balok adalah 200 cm³

# %% [markdown]
# #Konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# #Operator Perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8==8)
# Out:
# True

# %%
print(1 !=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9 !=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
berat_min  = 50
umur_max   = 25

tinggi_farel = 170
berat_farel  = 55
umur_farel   = 23

print(tinggi_farel >= tinggi_min and berat_farel >= berat_min and umur_farel <= umur_max)
# Out:
# True
